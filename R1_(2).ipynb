# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !pip install pymupdf
# Out:
# Requirement already satisfied: pymupdf in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (1.26.3)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import fitz

pdf_folder = "pdf"
text_folder = "texts"

os.makedirs(text_folder, exist_ok=True)

for filename in os.listdir(pdf_folder):
    if filename.lower().endswith(".pdf"):
        pdf_path = os.path.join(pdf_folder, filename)
        text_path = os.path.join(text_folder, filename.replace(".pdf", ".txt"))

        with fitz.open(pdf_path) as doc:
            text = ""
            for page in doc:
                text += page.get_text()

        with open(text_path, "w", encoding="utf-8") as f:
            f.write(text)

print(" Conversion completed. Text files are saved in 'texts' folder.")
# Out:
#  Conversion completed. Text files are saved in 'texts' folder.

# %%
import os

text_folder = "texts"
text_files = [os.path.join(text_folder, f) for f in os.listdir(text_folder) if f.endswith(".txt")]

all_text = ""
for file_path in text_files:
    with open(file_path, "r", encoding="utf-8") as f:
        all_text += f.read()

print(all_text[:500])
# Out:
# Introduction to Machine Learning
# 67577 - Fall, 2008
# Amnon Shashua
# School of Computer Science and Engineering
# The Hebrew University of Jerusalem
# Jerusalem, Israel
# arXiv:0904.3664v1  [cs.LG]  23 Apr 2009
# Contents
# 1
# Bayesian Decision Theory
# page 1
# 1.1
# Independence Constraints
# 5
# 1.1.1
# Example: Coin Toss
# 7
# 1.1.2
# Example: Gaussian Density Estimation
# 7
# 1.2
# Incremental Bayes Classiﬁer
# 9
# 1.3
# Bayes Classiﬁer for 2-class Normal Distributions
# 10
# 2
# Maximum Likelihood/ Maximum Entropy Duality
# 12
# 2.1
# ML and Em

# %%
chunk_size = 1000
text_chunks = [all_text[i:i+chunk_size] for i in range(0, len(all_text), chunk_size)]

print(f"Total number of chunks: {len(text_chunks)}")
print("First chunk:")
print(text_chunks[0])
# Out:
# Total number of chunks: 292
# First chunk:
# Introduction to Machine Learning
# 67577 - Fall, 2008
# Amnon Shashua
# School of Computer Science and Engineering
# The Hebrew University of Jerusalem
# Jerusalem, Israel
# arXiv:0904.3664v1  [cs.LG]  23 Apr 2009
# Contents
# 1
# Bayesian Decision Theory
# page 1
# 1.1
# Independence Constraints
# 5
# 1.1.1
# Example: Coin Toss
# 7
# 1.1.2
# Example: Gaussian Density Estimation
# 7
# 1.2
# Incremental Bayes Classiﬁer
# 9
# 1.3
# Bayes Classiﬁer for 2-class Normal Distributions
# 10
# 2
# Maximum Likelihood/ Maximum Entropy Duality
# 12
# 2.1
# ML and Empirical Distribution
# 12
# 2.2
# Relative Entropy
# 14
# 2.3
# Maximum Entropy and Duality ML/MaxEnt
# 15
# 3
# EM Algorithm: ML over Mixture of Distributions
# 19
# 3.1
# The EM Algorithm: General
# 21
# 3.2
# EM with i.i.d. Data
# 24
# 3.3
# Back to the Coins Example
# 24
# 3.4
# Gaussian Mixture
# 26
# 3.5
# Application Examples
# 27
# 3.5.1
# Gaussian Mixture and Clustering
# 27
# 3.5.2
# Multinomial Mixture and ”bag of words” Application 27
# 4
# Support Vector Machines and Kernel Functions
# 30
# 4.1
# Large Margin Classiﬁer as a Quadratic Linear Programmin

# %% [markdown]
# ## Choose and load an llm model
#
# ### Subtask:
# Select a suitable LLM model from Hugging Face that can be fine-tuned for summarization and text generation. Load the model and its tokenizer.

# %% [markdown]
# **Reasoning**:
# Import necessary classes from the transformers library and load a suitable pre-trained model and its tokenizer for text generation.

# %%
# !pip install ollama
# Out:
# Requirement already satisfied: ollama in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (0.5.3)
# Requirement already satisfied: httpx>=0.27 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from ollama) (2.11.7)
# Requirement already satisfied: anyio in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27->ollama) (4.10.0)
# Requirement already satisfied: certifi in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27->ollama) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27->ollama) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2.9->ollama) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2.9->ollama) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2.9->ollama) (0.4.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from anyio->httpx>=0.27->ollama) (1.3.1)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install bitsandbytes accelerate
# Out:
# Requirement already satisfied: bitsandbytes in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (0.46.1)
# Requirement already satisfied: accelerate in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (1.9.0)
# Requirement already satisfied: torch<3,>=2.2 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from bitsandbytes) (2.7.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from bitsandbytes) (2.2.6)
# Requirement already satisfied: filelock in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from torch<3,>=2.2->bitsandbytes) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from torch<3,>=2.2->bitsandbytes) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from torch<3,>=2.2->bitsandbytes) (1.14.0)
# Requirement already satisfied: networkx in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from torch<3,>=2.2->bitsandbytes) (3.5)
# Requirement already satisfied: jinja2 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from torch<3,>=2.2->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from torch<3,>=2.2->bitsandbytes) (2025.3.0)
# Requirement already satisfied: setuptools in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from torch<3,>=2.2->bitsandbytes) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\simon\appdata\roaming\python\python312\site-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in c:\users\simon\appdata\roaming\python\python312\site-packages (from accelerate) (7.0.0)
# Requirement already satisfied: pyyaml in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from accelerate) (6.0.2)
# Requirement already satisfied: huggingface_hub>=0.21.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from accelerate) (0.34.3)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from accelerate) (0.5.3)
# Requirement already satisfied: requests in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from sympy>=1.13.3->torch<3,>=2.2->bitsandbytes) (1.3.0)
# Requirement already satisfied: colorama in c:\users\simon\appdata\roaming\python\python312\site-packages (from tqdm>=4.42.1->huggingface_hub>=0.21.0->accelerate) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch<3,>=2.2->bitsandbytes) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2025.7.14)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests

# Choose the model you want to use
model_name = "mistral:latest"  # or "granite3.3:2b", "gpt-oss:20b"

# Send a prompt to Ollama
response = requests.post(
    "http://localhost:11434/api/generate",
    json={
        "model": model_name,
        "prompt": "Write a short poem about AI and coding."
    }
)

# Ollama streams the output as chunks, so let's print them
for line in response.iter_lines():
    if line:
        data = line.decode('utf-8')
        print(data)
# Out:
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:26.6565401Z","response":" In","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:26.7784864Z","response":" digital","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:26.8890168Z","response":" real","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:26.9998215Z","response":"ms","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:27.1115072Z","response":" where","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:27.2224839Z","response":" thoughts","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:27.3326154Z","response":" take","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:27.442856Z","response":" flight","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:27.5538672Z","response":",","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:27.6658208Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:27.7767863Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:27.8878314Z","response":"C","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:27.9981695Z","response":"od","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:28.1103069Z","response":"ers","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:28.2142053Z","response":" dance","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:28.3084597Z","response":" with","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:28.4099669Z","response":" stars","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:28.5121273Z","response":" of","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:28.6155776Z","response":" light","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:28.7189165Z","response":",","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:28.8237689Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:28.9267556Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:29.02968Z","response":"Com","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:29.1338524Z","response":"pose","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:29.2374491Z","response":" the","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:29.3397835Z","response":" rhythm","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:29.4454329Z","response":" of","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:29.5512934Z","response":" logic","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:29.6580894Z","response":" neat","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:29.7645701Z","response":",","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:29.8702987Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:29.9809916Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:30.0849599Z","response":"In","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:30.1907678Z","response":" binary","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:30.2997865Z","response":" vers","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:30.4146152Z","response":"es","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:30.5238769Z","response":" they","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:30.6336864Z","response":" meet","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:30.7418562Z","response":".","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:30.8513099Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:30.961575Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:31.0703382Z","response":"Sil","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:31.177713Z","response":"icon","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:31.2842152Z","response":" minds","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:31.3972177Z","response":" with","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:31.5080184Z","response":" human","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:31.6202005Z","response":" heart","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:31.7292086Z","response":",","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:31.8411155Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:31.953255Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:32.0643186Z","response":"AI","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:32.175832Z","response":" we","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:32.2887541Z","response":"aves","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:32.4012454Z","response":" an","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:32.5226019Z","response":" art","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:32.6373404Z","response":"ful","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:32.7517728Z","response":" start","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:32.8676425Z","response":",","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:32.9833263Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:33.0960481Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:33.2088285Z","response":"P","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:33.3243298Z","response":"rec","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:33.4382531Z","response":"ision","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:33.5487936Z","response":" in","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:33.6645442Z","response":" each","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:33.7790148Z","response":" line","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:33.893089Z","response":" it","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:34.0060608Z","response":" s","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:34.1197902Z","response":"ings","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:34.2308612Z","response":",","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:34.3432359Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:34.4603767Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:34.5786453Z","response":"To","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:34.6892187Z","response":" patterns","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:34.8010673Z","response":",","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:34.9155228Z","response":" algorithms","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:35.0260682Z","response":",","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:35.1378025Z","response":" where","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:35.2526307Z","response":" it","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:35.3655192Z","response":" cl","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:35.4792091Z","response":"ings","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:35.5932792Z","response":".","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:35.7048947Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:35.8203545Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:35.9338882Z","response":"A","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:36.048464Z","response":" dance","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:36.1645664Z","response":" of","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:36.2787375Z","response":" ones","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:36.3889563Z","response":" and","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:36.5024817Z","response":" z","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:36.620999Z","response":"eros","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:36.7317613Z","response":" grand","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:36.8441943Z","response":",","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:36.9611582Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:37.07373Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:37.1855387Z","response":"C","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:37.2972907Z","response":"raft","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:37.4098839Z","response":"ing","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:37.5224735Z","response":" life","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:37.6375936Z","response":" from","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:37.7481519Z","response":" sil","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:37.8604627Z","response":"icon","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:37.9751994Z","response":" sand","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:38.0854648Z","response":",","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:38.1999714Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:38.3162883Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:38.4311283Z","response":"Un","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:38.5450342Z","response":"fold","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:38.6628236Z","response":"ing","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:38.7770188Z","response":" dreams","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:38.890292Z","response":" in","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:39.0032583Z","response":" lines","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:39.1209951Z","response":" of","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:39.237271Z","response":" code","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:39.3552061Z","response":",","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:39.4586383Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:39.5614469Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:39.6575253Z","response":"On","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:39.7546981Z","response":" screens","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:39.8513215Z","response":" that","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:39.9523522Z","response":" glow","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:40.048125Z","response":" with","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:40.1498914Z","response":" shining","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:40.2467125Z","response":" o","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:40.3428365Z","response":"de","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:40.4435831Z","response":".","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:40.543531Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:40.641893Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:40.740449Z","response":"In","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:40.837031Z","response":"visible","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:40.9349441Z","response":" threads","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:41.0347634Z","response":" they","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:41.1321784Z","response":" inter","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:41.2291049Z","response":"tw","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:41.3265022Z","response":"ine","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:41.4246824Z","response":",","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:41.5246505Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:41.6315675Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:41.7370607Z","response":"T","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:41.8439976Z","response":"ales","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:41.9533548Z","response":" of","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:42.0574572Z","response":" creation","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:42.1628145Z","response":",","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:42.2681977Z","response":" love","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:42.3739772Z","response":",","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:42.4789458Z","response":" and","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:42.5874483Z","response":" sign","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:42.6918366Z","response":",","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:42.7994364Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:42.905406Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:43.0158432Z","response":"The","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:43.1224649Z","response":" language","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:43.2311749Z","response":" of","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:43.3417291Z","response":" the","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:43.4555148Z","response":" soul","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:43.567766Z","response":" re","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:43.6775382Z","response":"defined","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:43.7923577Z","response":",","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:43.9012626Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:44.0154554Z","response":"\n","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:44.1246988Z","response":"By","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:44.2369084Z","response":" hands","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:44.3540029Z","response":" that","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:44.4684218Z","response":" guide","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:44.5871618Z","response":" AI","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:44.7010787Z","response":"'","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:44.8229346Z","response":"s","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:44.9378946Z","response":" mind","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:45.0492442Z","response":".","done":false}
# {"model":"mistral:latest","created_at":"2025-08-11T02:22:45.1666088Z","response":"","done":true,"done_reason":"stop","context":[3,29473,12786,1032,3253,16835,1452,16875,1072,23131,29491,4,29473,1328,7921,2121,1801,1738,8171,2156,10082,29493,781,781,29511,1118,1172,10541,1163,8216,1070,2829,29493,781,781,1931,4664,1040,20602,1070,12176,18498,29493,781,781,1425,10904,4270,1042,1358,3415,29491,781,781,23426,4558,15666,1163,3698,3799,29493,781,781,12509,1246,4178,1164,2292,1775,1917,29493,781,781,29521,4122,2290,1065,2198,2175,1146,1036,1510,29493,781,781,2319,12301,29493,19307,29493,1738,1146,1301,1510,29491,781,781,29509,10541,1070,5181,1072,1454,11435,4255,29493,781,781,29511,3637,1056,2179,1245,3726,4558,7598,29493,781,781,2501,14711,1056,13000,1065,5483,1070,3464,29493,781,781,3254,19562,1137,23766,1163,27343,1057,1218,29491,781,781,1425,14324,18575,1358,1559,8075,1241,29493,781,781,29506,2998,1070,10081,29493,2784,29493,1072,2260,29493,781,781,1782,4610,1070,1040,8005,1080,12266,29493,781,781,2698,3806,1137,9095,16875,29510,29481,3041,29491],"total_duration":25958522100,"load_duration":5137734500,"prompt_eval_count":13,"prompt_eval_duration":2291941400,"eval_count":170,"eval_duration":18523734400}

# %%
import json
from pathlib import Path

# Path to your folder with .txt research papers
input_dir = Path(r"C:\Users\simon\Desktop\pdf2\new\texts")  
output_file = Path(r"C:\Users\simon\Desktop\pdf2\new\my_model\dataset.jsonl")

CHUNK_SIZE = 1000

with open(output_file, "w", encoding="utf-8") as out:
    for file in input_dir.glob("*.txt"):
        text = file.read_text(encoding="utf-8").strip()

        # Split into chunks
        chunks = [text[i:i + CHUNK_SIZE] for i in range(0, len(text), CHUNK_SIZE)]

        for chunk in chunks:
            # Each chunk is stored as a completion, with an empty prompt
            json.dump({
                "prompt": "",
                "completion": chunk
            }, out, ensure_ascii=False)
            out.write("\n")

print(f"✅ Dataset saved to {output_file}")
# Out:
# ✅ Dataset saved to C:\Users\simon\Desktop\pdf2\new\my_model\dataset.jsonl

# %%
# !pip install chromadb ollama requests
# Out:
# Requirement already satisfied: chromadb in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (1.0.16)
# Requirement already satisfied: ollama in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (0.5.3)
# Requirement already satisfied: requests in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (2.32.4)
# Requirement already satisfied: build>=1.0.3 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pydantic>=1.9 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (2.11.7)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.35.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (2.2.6)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (4.14.1)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.22.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.36.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.36.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.36.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.21.4)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.74.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (3.11.1)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (14.1.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from requests) (2025.7.14)
# Requirement already satisfied: packaging>=19.1 in c:\users\simon\appdata\roaming\python\python312\site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: pyproject_hooks in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\simon\appdata\roaming\python\python312\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->chromadb) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.27.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: coloredlogs in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.31.1)
# Requirement already satisfied: sympy in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.36.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.36.0)
# Requirement already satisfied: opentelemetry-proto==1.36.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.36.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.57b0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=1.9->chromadb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=1.9->chromadb) (0.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\simon\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.34.3)
# Requirement already satisfied: filelock in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.3.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from typer>=0.9.0->chromadb) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (4.67.1)
# Requirement already satisfied: colorama in c:\users\simon\appdata\roaming\python\python312\site-packages (from tqdm) (0.4.6)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import requests
import chromadb
from pathlib import Path
from tqdm import tqdm  # progress bar

# ------------------------
# 1. Settings
# ------------------------
MODEL_NAME = "mistral:latest"              # Model for answering
EMBED_MODEL = "nomic-embed-text"           # Model for embeddings
OLLAMA_API = "http://localhost:11434"
DATA_DIR = Path(r"C:\Users\simon\Desktop\pdf2\research_papers")  # Folder with .txt papers

# Directory where ChromaDB will store the database
CHROMA_DB_DIR = Path(r"C:\Users\simon\Desktop\pdf2\chroma_db")

# ------------------------
# 2. ChromaDB setup (persist to disk)
# ------------------------
chroma_client = chromadb.PersistentClient(path=str(CHROMA_DB_DIR))
collection = chroma_client.get_or_create_collection(name="research_papers")

# ------------------------
# 3. Function to get embeddings from Ollama
# ------------------------
def get_embedding(text: str):
    r = requests.post(f"{OLLAMA_API}/api/embeddings", json={
        "model": EMBED_MODEL,
        "prompt": text
    })
    r.raise_for_status()
    return r.json()["embedding"]

# ------------------------
# 4. Load documents into memory for processing
# ------------------------
all_chunks = []
for file in DATA_DIR.glob("*.txt"):
    text = file.read_text(encoding="utf-8").strip()
    chunks = [text[i:i + 500] for i in range(0, len(text), 500)]
    all_chunks.extend(chunks)

print(f"📄 Found {len(all_chunks)} chunks to embed.")

# ------------------------
# 5. Embed and store with progress bar
# ------------------------
existing_ids = set(collection.get()["ids"])  # Avoid re-embedding duplicates

for idx, chunk in enumerate(tqdm(all_chunks, desc="Embedding chunks", unit="chunk")):
    chunk_id = str(idx)
    if chunk_id in existing_ids:
        continue  # Skip if already embedded
    emb = get_embedding(chunk)
    collection.add(
        ids=[chunk_id],
        documents=[chunk],
        embeddings=[emb]
    )

print("✅ All chunks embedded and stored in ChromaDB.")

# ------------------------
# 6. Query function
# ------------------------
def ask_ollama_with_context(question, top_k=3):
    q_emb = get_embedding(question)
    results = collection.query(query_embeddings=[q_emb], n_results=top_k)
    context = "\n\n".join(results["documents"][0])

    prompt = f"Use the following research context to answer the question:\n\n{context}\n\nQuestion: {question}"

    response = requests.post(f"{OLLAMA_API}/api/generate", json={
        "model": MODEL_NAME,
        "prompt": prompt,
        "stream": False
    })
    return response.json().get("response", "")

# ------------------------
# 7. Example query
# ------------------------
user_question = "Explain the latest advancements in AI from the research papers."
print("\n🤖 Answer:\n", ask_ollama_with_context(user_question))
# Out:
# 📄 Found 0 chunks to embed.
# Embedding chunks: 0chunk [00:00, ?chunk/s]
# ✅ All chunks embedded and stored in ChromaDB.
# 🤖 Answer:
#   In recent times, there have been significant advancements in Artificial Intelligence (AI) as evidenced by various research papers. Here are some key developments:
#
# 1. DeepMind's AlphaCode: In a groundbreaking development, Google's DeepMind introduced AlphaCode, an AI model that can teach itself to play video games without human intervention. This marks a significant step towards creating general-purpose learning algorithms that can adapt to a wide range of tasks.
#
# 2. AI in Drug Discovery: Researchers from the University of Washington developed an AI model called DeepChemNet, which can predict chemical reactions and aid in the development of new drugs. The model could potentially speed up drug discovery and reduce costs associated with traditional methods.
#
# 3. Improvements in Natural Language Processing (NLP): Recent advancements in NLP include the introduction of T0 and T5 models by Google, which have shown impressive performance in a variety of tasks such as summarization, translation, and question-answering. These models use transformer architectures that allow them to understand context better.
#
# 4. Advancements in AI Ethics: Researchers are increasingly focusing on the ethical implications of AI. A notable paper by researchers at MIT discusses fairness, accountability, and transparency (FAT) as crucial considerations for AI development. This shift aims to ensure that AI systems do not exacerbate existing societal biases.
#
# 5. Progress in Reinforcement Learning: Researchers have made significant strides in reinforcement learning, a type of machine learning where an agent learns to make decisions by taking actions in an environment to achieve a goal. DeepMind's MuZero algorithm, for example, can play a wide variety of games at a high level without being told the rules of each game explicitly.
#
# 6. AI and Climate Change: Researchers are using AI to predict and mitigate the effects of climate change. For instance, scientists at Columbia University used AI to create high-resolution maps of the world's forests, providing valuable data for monitoring deforestation and forest regeneration.
#
# 7. Advancements in Robotics: In robotics, SoftHand, a soft robotic hand developed by the Max Planck Institute for Intelligent Systems, can handle fragile objects as delicately as a human hand due to its flexible design and AI control system.
#
# These advancements show that AI research is continually evolving, with promising developments in various fields such as gaming, drug discovery, natural language processing, ethics, reinforcement learning, climate change, and robotics.

# %%
# !pip install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (5.42.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (4.10.0)
# Requirement already satisfied: brotli>=1.1.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.116.1)
# Requirement already satisfied: ffmpy in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.6.1)
# Requirement already satisfied: gradio-client==1.11.1 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (1.11.1)
# Requirement already satisfied: groovy~=0.1 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.33.5 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.34.3)
# Requirement already satisfied: jinja2<4.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (2.2.6)
# Requirement already satisfied: orjson~=3.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (3.11.1)
# Requirement already satisfied: packaging in c:\users\simon\appdata\roaming\python\python312\site-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (11.3.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (2.11.7)
# Requirement already satisfied: pydub in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.12.8)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.47.2)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.16.0)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (4.14.1)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio) (0.35.0)
# Requirement already satisfied: fsspec in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio-client==1.11.1->gradio) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from gradio-client==1.11.1->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: certifi in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (3.18.0)
# Requirement already satisfied: requests in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.4.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0,>=0.12->gradio) (14.1.0)
# Requirement already satisfied: colorama in c:\users\simon\appdata\roaming\python\python312\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\simon\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface-hub<1.0,>=0.33.5->gradio) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\simon\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface-hub<1.0,>=0.33.5->gradio) (2.5.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
result = collection.get()
print(result.keys())
print(f"Total vectors: {len(result['ids'])}")
print(result['ids'][:10])  # print first 10 ids
# Out:
# dict_keys(['ids', 'embeddings', 'documents', 'uris', 'included', 'data', 'metadatas'])
# Total vectors: 0
# []

# %%
# gradio_rag.py
import os
import json
import requests
import chromadb
import gradio as gr
from pathlib import Path
from tqdm import tqdm

# ------------------------
# 1. Settings 
# ------------------------
MODEL_NAME = "mistral:latest"      
EMBED_MODEL = "nomic-embed-text"           # embedding model name (if Ollama supports it)
OLLAMA_API = "http://localhost:11434"
DATA_DIR = Path(r"C:\Users\simon\Desktop\pdf2\new\texts")  
CHROMA_DB_DIR = Path(r"C:\Users\simon\Desktop\pdf2\new\chroma_db")   # persistent storage

CHUNK_SIZE = 5000

# ------------------------
# 2. ChromaDB setup (persistent)
# ------------------------
# Create persistent client (Chromadb >= certain versions)
chroma_client = chromadb.PersistentClient(path=str(CHROMA_DB_DIR))
collection = chroma_client.get_or_create_collection(name="research_papers")

# ------------------------
# 3. Embedding function (uses Ollama embeddings endpoint)
# ------------------------
def get_embedding(text: str):
    r = requests.post(f"{OLLAMA_API}/api/embeddings", json={
        "model": EMBED_MODEL,
        "prompt": text
    })
    r.raise_for_status()
    return r.json()["embedding"]

# ------------------------
# 4. Helper: create chunks from .txt files
# ------------------------
def load_all_chunks(data_dir: Path, chunk_size: int = CHUNK_SIZE):
    chunks = []
    files = sorted(list(data_dir.glob("*.txt")))
    for file in files:
        text = file.read_text(encoding="utf-8").strip()
        if not text:
            continue
        file_chunks = [text[i:i + chunk_size] for i in range(0, len(text), chunk_size)]
        chunks.extend(file_chunks)
    return chunks

# ------------------------
# 5. Build / update index (called by Gradio button)
#    Uses gr.Progress to show visual progress in the UI.
# ------------------------
def build_index():
    all_chunks = load_all_chunks(DATA_DIR, CHUNK_SIZE)
    total = len(all_chunks)
    if total == 0:
        return "No .txt files found in the research_papers folder."

    existing_ids = set()
    if collection.count() > 0:
        result = collection.get(limit=collection.count())
        existing_ids = set(result.get("ids", []))

    progress = gr.Progress()  # no arguments here

    for idx, chunk in enumerate(all_chunks):
        chunk_id = str(idx)
        if chunk_id in existing_ids:
            progress.progress(idx + 1, desc=f"Skipping {idx + 1}/{total} (exists)")
            continue
        try:
            emb = get_embedding(chunk)
        except Exception as e:
            return f"Error getting embedding from Ollama: {e}"
        collection.add(ids=[chunk_id], documents=[chunk], embeddings=[emb])
        progress.progress(idx + 1, desc=f"Embedded {idx + 1}/{total}")

    return f"Index built/updated. {collection.count()} total vectors stored."


# ------------------------
# 6. Streaming query function (returns a generator for Gradio streaming)
# ------------------------
def ask_with_context_stream(question: str, top_k: int = 3):
    if not question or question.strip() == "":
        yield "Please enter a question."
        return

    # Get question embedding
    try:
        q_emb = get_embedding(question)
    except Exception as e:
        yield f"Error getting question embedding: {e}"
        return

    # Retrieve top_k docs
    try:
        results = collection.query(query_embeddings=[q_emb], n_results=top_k)
    except Exception as e:
        yield f"Error querying ChromaDB: {e}"
        return

    docs = results.get("documents", [[]])[0]
    if not docs:
        context = ""
    else:
        context = "\n\n".join(docs)

    prompt = (
        "Use the following research context to answer the question concisely and accurately:\n\n"
        f"{context}\n\nQuestion: {question}\nAnswer:"
    )

    # Stream generation from Ollama
    stream_url = f"{OLLAMA_API}/api/generate"
    payload = {"model": MODEL_NAME, "prompt": prompt, "stream": True}

    try:
        with requests.post(stream_url, json=payload, stream=True, timeout=120) as r:
            r.raise_for_status()
            accumulated = ""
            # Ollama sends server-sent-events like lines; parse JSON parts
            for line in r.iter_lines():
                if line:
                    try:
                        text_line = line.decode("utf-8").strip()
                        # many Ollama versions send `data: {...}` SSE lines
                        if text_line.startswith("data:"):
                            json_part = text_line[len("data:"):].strip()
                        else:
                            json_part = text_line
                        # sometimes it sends "[DONE]" or blank
                        if json_part in ("[DONE]", ""):
                            continue
                        # parse as JSON
                        payload_chunk = json.loads(json_part)
                        # common key is 'response' or nested 'choices'
                        chunk_text = ""
                        if isinstance(payload_chunk, dict):
                            # Most simple case
                            chunk_text = payload_chunk.get("response", "")
                            if not chunk_text and "choices" in payload_chunk:
                                # try to parse choices -> delta/content
                                choices = payload_chunk["choices"]
                                if choices and isinstance(choices, list):
                                    # try common fields
                                    for ch in choices:
                                        if isinstance(ch, dict):
                                            chunk_text = chunk_text + ch.get("delta", {}).get("content", "") or ch.get("text", "") or ""
                        if chunk_text:
                            accumulated += chunk_text
                            yield accumulated  # yield accumulated text so UI updates incrementally
                    except json.JSONDecodeError:
                        # ignore unparsable chunks
                        continue
    except Exception as e:
        yield f"Error calling Ollama generate API: {e}"
        return

    yield accumulated  # final output

# ------------------------
# 7. Build Gradio interface
# ------------------------
with gr.Blocks(title="Ollama RAG Demo") as demo:
    gr.Markdown("Research papers Analysis")
    with gr.Row():
        with gr.Column(scale=2):
            q_input = gr.Textbox(label="Question", placeholder="e.g. What is Machine learning?", lines=2)
            top_k = gr.Slider(minimum=1, maximum=8, value=3, step=1, label="Top K retrieved chunks")
            ask_btn = gr.Button("Ask (stream)")
            output = gr.Textbox(label="Model answer (streamed)", lines=10)
        with gr.Column(scale=1):
            build_btn = gr.Button("Build / Update Index")
            status = gr.Textbox(label="Status", lines=6)

    # Wire the buttons
    build_btn.click(fn=build_index, inputs=None, outputs=[status])
    # For streaming, set outputs to the output textbox; Gradio will stream generator yields here
    ask_btn.click(fn=ask_with_context_stream, inputs=[q_input, top_k], outputs=[output])

if __name__ == "__main__":
    demo.launch(server_name="0.0.0.0", server_port=7870, share=False)
# Out:
# * Running on local URL:  http://0.0.0.0:7870
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://localhost:7870/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "c:\Users\simon\AppData\Local\Programs\Python\Python312\Lib\site-packages\gradio\queueing.py", line 626, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\simon\AppData\Local\Programs\Python\Python312\Lib\site-packages\gradio\route_utils.py", line 350, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\simon\AppData\Local\Programs\Python\Python312\Lib\site-packages\gradio\blocks.py", line 2250, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\simon\AppData\Local\Programs\Python\Python312\Lib\site-packages\gradio\blocks.py", line 1757, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\simon\AppData\Local\Programs\Python\Python312\Lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\simon\AppData\Local\Programs\Python\Python312\Lib\site-packages\anyio\_backends\_asyncio.py", line 2476, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "c:\Users\simon\AppData\Local\Programs\Python\Python312\Lib\site-packages\anyio\_backends\_asyncio.py", line 967, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\simon\AppData\Local\Programs\Python\Python312\Lib\site-packages\gradio\utils.py", line 917, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\simon\AppData\Local\Temp\ipykernel_21676\3066675874.py", line 69, in build_index
#     with gr.Progress(total=total) as progress:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: Progress.__init__() got an unexpected keyword argument 'total'
